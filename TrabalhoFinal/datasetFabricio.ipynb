# %%
import os
import pandas as pd
from androguard.misc import AnalyzeAPK, AnalyzeDex
from androguard.core.bytecodes.axml import ARSCParser
from androguard.core.bytecodes.axml import AXMLPrinter, ARSCResTableEntry
from androguard.core.bytecodes.dvm import DalvikVMFormat
import json
import hashlib

# %%
az = pd.read_csv('az18.csv')
androDi = pd.read_csv('azBalanceado.csv')

# %%
def getResources(a):
    rids = []
    resEntry = []
    resTable = str(a.get_android_resources().get_public_resources(a.get_package()))
    for res in resTable.split(' '):
        if 'id=' in res:
            if res.split('"')[1] not in rids:
                rids.append(res.split('"')[1])
    for rid in rids:
        resEntry.append(a.get_android_resources().get_resource_xml_name(int(rid,0)).split('/')[1])
    return resEntry

# %%
def getPackages(d):
    pkgs = []
    for c in d.get_classes():
        s = str(c.get_name()[1:].split('$')[0]).split('/')
        x = '/'.join(s[:-1])
        if x not in pkgs:
            pkgs.append(x)
    return pkgs

# %%
def getActionCategory(a):
    manifest = str(a.get_android_manifest_axml().get_xml(pretty=True)).split('\\n')
    action = []
    category = []
    for line in manifest:
        if 'action' in line:
            if line.split('"')[1] not in action:
                action.append(line.split('"')[1])
        if 'category' in line:
            if line.split('"')[1] not in category:
                category.append(line.split('"')[1])
    return action, category

# %%
def getCerts(a):
    cert = []
    for x in a.get_certificates():
        cert.append(x.subject.human_friendly)
    return cert

# %%
def getMethods(d):
    methods = []
    for m in d.get_methods():
        if m.name not in methods:
            methods.append(m.name)
    return methods

# %%
def sha256(apk, label):
    if label:
        apk='apksAz18/malware/'+apk+'.apk'
    else:
        apk='apksAz18/normal/'+apk+'.apk'
    sha256 = hashlib.sha256()
    with open(apk, 'rb') as f:
        while True:
            data = f.read(65536)
            if not data:
                break
            sha256.update(data)
    return sha256.hexdigest()

# %%
def classifyApk(apk):
    data = []
    print(apk)
    malware = os.listdir('apksAz18/malware')
    normal = os.listdir('apksAz18/normal')
    label = False
    azData = pd.DataFrame()
    if apk+'.apk' in normal:
        azData = az[(az['pkg_name']==apk) & (az['vt_detection']==0)]
    else:
        azData = az[(az['pkg_name']==apk) & (az['vt_detection']>5)]
        label = True
    if azData.shape[0]>1:
        azData = az[az['sha256']==sha256(apk, label).upper()]
    if len(azData) == 1:
        data.append(azData.sha256.values[0].lower())
        data.append(azData.sha1.values[0].lower())
        data.append(azData.md5.values[0].lower())
        data.append(apk)
        data.append(azData.vt_detection.values[0])
        data.append(azData.dex_size.values[0])
        data.append(azData.apk_size.values[0])
        apkPath = ''
        if int(azData.vt_detection.values[0]) > 5:
            apkPath = 'apksAz18/malware/'+apk+'.apk'
        else:
            apkPath = 'apksAz18/normal/'+apk+'.apk'
        a, d, dx = AnalyzeAPK(apkPath)
        d = DalvikVMFormat(a.get_dex())
        data.append(a.get_target_sdk_version())
        data.append(a.get_min_sdk_version())
        data.append(a.get_max_sdk_version())
        data.append(azData.dex_date.values[0])
        data.append(azData.vt_scan_date.values[0])
        data.append(getResources(a))
        data.append(getPackages(d))
        data.append(a.get_permissions())
        data.append(a.get_activities())
        action, category = getActionCategory(a)
        data.append(action)
        data.append(category)
        data.append(a.get_features())
        data.append(getMethods(d))
        data.append(getCerts(a))
        data.append(azData.markets.values[0])
        with open('type.json', 'r') as f:
            try:
                data.append(json.load(f)[azData.sha256.values[0].lower()])
            except:
                print('sem tipo')
                data.append('')
        with open('family.json', 'r') as f:
            try:
                data.append(json.load(f)[azData.sha256.values[0].lower()])
            except:
                print('sem familia')
                data.append('')
        if int(azData.vt_detection.values[0]) == 0:
            data.append(0)
        else:
            data.append(1)
        return data
    else:
        print('apk não encontrado')

# %%
lst=[]
data = pd.DataFrame(columns = ['meta.sha256','meta.sha1','meta.md5','meta.pkg.name','meta.vt.score','meta.dex.size','meta.apk.size','manifest.tarsdk','manifest.minsdk','manifest.maxsdk','meta.dex.date','meta.vt.date','resource.entry','source.class.package','manifest.permission','manifest.activity','manifest.action','manifest.category','manifest.feature','source.method.name','certificate.owner','meta.market','label.type','label.family','label'])
for apk in androDi['Apk']:
    lst = classifyApk(apk)
    data = data.append(pd.DataFrame([lst], columns=data.columns),ignore_index=True)
# Out:
# com.ForntYardIdeas.eshall
# sem tipo
# sem familia
# com.narasimata.najwashihab
# sem tipo
# sem familia
# com.Ideasforaquascape.uwiapps
# sem tipo
# sem familia
# com.greatesthitsallalbum.maroon5
# sem tipo
# sem familia
# com.innockstudios.balloonarcher
# sem tipo
# sem familia
# com.Sportstudio.PROSOCCERSTARLEAGUE
# sem tipo
# sem familia
# free.stock.guru
# sem tipo
# sem familia
# com.pastarecipes.sangdroib
# sem tipo
# sem familia
# com.OfficeBuildingDesign.lukoni
# sem tipo
# sem familia
# sdteamnew.fastphofc.com.ph
# sem tipo
# sem familia
# com.resepayamsausmentegalezat.resepmasakandanminuman.toptrandresepmasakanapps.mesotheliomalawfirm
# sem tipo
# sem familia
# com.lemi.xuanhuan
# sem tipo
# sem familia
# com.WomenBra.trascodroid
# sem tipo
# sem familia
# com.programsdesigningfor.podksvad
# sem tipo
# sem familia
# com.mt354.adzanpakmayone
# sem tipo
# sem familia
# com.saintlucia.fmradioonline.radiostationtunner
# sem tipo
# sem familia
# com.dc.asg
# sem tipo
# sem familia
# com.nlabs.Milestone
# sem tipo
# sem familia
# com.megaaccount.romenticsongs
# sem tipo
# sem familia
# jacob.brown.photoframes.photoeditor.lighthouse
# sem tipo
# sem familia
# tapto.tapto
# sem tipo
# sem familia
# com.flyingcap.grand.immortal.superheroes.fighting.games
# sem tipo
# sem familia
# de.semerkandonline.mobil
# sem tipo
# sem familia
# com.retrohairstyletutorials.ghock
# sem tipo
# sem familia
# com.abedmoussa140.app909
# sem tipo
# sem familia
# com.ririfence
# sem tipo
# sem familia
# eduplay.home.masud.bankingapp
# sem tipo
# sem familia
# com.androdev22.ceilingpremium3d
# sem tipo
# sem familia
# com.drivinglicencekaisebanwaye.gurleen
# sem tipo
# sem familia
# com.rachittechnology.kenyasthenarcoticdrugsandpsychotropicsubstancescontrolact1994
# sem tipo
# sem familia
# pras.prasetio.CNC
# sem tipo
# sem familia
# com.mtn1app
# sem tipo
# sem familia
# com.radioamfmfreeCanadaonlineradio.BigOne1TorontoOnlineRadioFMOnlineBigOne1TorontoOnline
# sem tipo
# sem familia
# com.psba.dokkantoolapk
# sem tipo
# sem familia
# com.suvdriving.aiuadi
# sem tipo
# sem familia
# com.fpe.hub
# sem tipo
# sem familia
# com.techblinks.medicalnews.alert
# sem tipo
# sem familia
# com.desertstormfront.android.lite
# sem tipo
# sem familia
# com.vo.talk
# sem tipo
# sem familia
# com.primbonmenghitungpindahanrumah.primbon
# sem tipo
# sem familia
# com.a2fahmi.tadarusnote
# sem tipo
# sem familia
# com.sma.pl.van.lith
# sem tipo
# sem familia
# com.iflexforms
# sem tipo
# sem familia
# com.HouseholdDesign.lukoni
# sem tipo
# sem familia
# com.yosoft.tamildailyrasipalan
# sem tipo
# sem familia
# com.radioamfmCanadaonlineradio.CFQMMaxFM1039Moncton1039FMRadioFMOnlineMoncton1039FM
# sem tipo
# sem familia
# com.syclonapps.gardenstonetilesdesign
# sem tipo
# sem familia
# com.digitalindia.ignoustudents
# sem tipo
# sem familia
# das.lastname
# sem tipo
# sem familia
# com.bukukuncigitar.Rayadeveloper
# sem tipo
# sem familia
# com.newlebanonversiontwo
# sem tipo
# sem familia
# com.VegasCasinoGames.LostTreasureSlots
# sem tipo
# sem familia
# com.WomenHairColorIdeas.idak
# sem tipo
# sem familia
# es.bandomovil.elfranco.informa
# sem tipo
# sem familia
# com.rxwikiplus.a7322554788
# sem tipo
# sem familia
# org.avmg.leideba
# sem tipo
# sem familia
# com.antingemasputihbulat.DodiApps
# sem tipo
# sem familia
# app.packs.ajedrezmotores
# sem tipo
# sem familia
# com.chessboard.livingroomfabricsofaideas
# sem tipo
# sem familia
# com.Kidcastle.Easter2019
# sem tipo
# sem familia
# com.lyndoyustudio.boyhairstyliststickers
# sem tipo
# sem familia
# ru.azurinteractive.robotwarfarevr
# sem tipo
# sem familia
# com.BettaFishWallpaper.pictdroid
# sem tipo
# sem familia
# bndu.dual.pkgarden
# sem tipo
# sem familia
# org.redidea.dict
# sem tipo
# sem familia
# popupmenu.com.halkmuzikleri
# sem tipo
# sem familia
# www.christianmatrimonyworld.com.christianmatrimonyworld
# sem tipo
# sem familia
# com.africanfashioncouple.btxapp
# sem tipo
# sem familia
# com.neemo.pizzariasaolucas
# sem tipo
# sem familia
# com.goder.busquerysystemlon
# sem tipo
# sem familia
# com.kumpulankatabijakmotivasihidupuntukdirisendiri.untaiankatapenuhmakna.onlineforextrading
# sem tipo
# sem familia
# cobo.wallet
# sem tipo
# sem familia
# com.japanesesongs.thejoker
# sem tipo
# sem familia
# www.cartermobil.web.id.cartersewamobilpurwokerto
# sem tipo
# sem familia
# com.XBannerDesignInteresting.lukoni
# sem tipo
# sem familia
# com.HomeDesk.trascodroid
# sem tipo
# sem familia
# com.gaces.pnpkyr
# sem tipo
# sem familia
# com.kellerdev.HALT
# sem tipo
# sem familia
# com.iss.classadlister
# sem tipo
# sem familia
# com.kend.marr
# sem tipo
# sem familia
# patshtecno.com
# sem tipo
# sem familia
# com.NewTVShelfDesign.sitd212
# sem tipo
# sem familia
# br.com.transitopoars.android
# sem tipo
# sem familia
# com.katakatasindiranhalusdanpedasnamunbijakterbaru.forextrandingonline
# sem tipo
# sem familia
# com.AndyYip.DiscountApp
# sem tipo
# sem familia
# com.uzairon.kh
# sem tipo
# sem familia
# com.kumpulanhaditsrasulullahsawkatakatahikmahnabimuhammad.fahrihadist01.tradingnewinsurancelife
# sem tipo
# sem familia
# com.smashgames.pongcoop
# sem tipo
# sem familia
# com.wakk.jobb
# sem tipo
# sem familia
# apps.infinite.barbequegrillsound
# sem tipo
# sem familia
# com.bianla.international
# sem tipo
# sem familia
# com.sohof.Morocco
# sem tipo
# sem familia
# com.diytoiletpaperholder.bordinas
# sem tipo
# sem familia
# net.phcyber.httpssl
# sem tipo
# sem familia
# com.hcs.android
# sem tipo
# sem familia
# com.resepsaladfruitsalad.resepmasakandanminuman.toptrandresepmasakanapps.mesotheliomalawfirm
# sem tipo
# sem familia
# com.kar.safaris
# sem tipo
# sem familia
# com.syclonapps.basementegresswindow
# sem tipo
# sem familia
# com.CollectionOfStoneRings.saydroid
# sem tipo
# sem familia
# kr.e777.daeriya.jang1112
# sem tipo
# sem familia
# com.SugarDaddy.HawkSoundRingtone
# sem tipo
# sem familia
# com.tygame.game50
# sem tipo
# sem familia
# com.malaysia90an.thejoker
# sem tipo
# sem familia
# com.animalorigami.fellix
# sem tipo
# sem familia
# com.lasertagpro.enemy
# sem tipo
# sem familia
# org.doando.doando
# sem tipo
# sem familia
# com.batampos.web
# sem tipo
# sem familia
# com.arteoning.fut19draftsimulator
# sem tipo
# sem familia
# com.lagumelayu.thejoker
# sem tipo
# sem familia
# kemco.execreate.asdivinehearts2
# sem tipo
# sem familia
# com.tfh.thefruithut
# sem tipo
# sem familia
# com.DesignUniqueUrn.kesumaapp
# sem tipo
# sem familia
# com.JutDube.TheLastJediPianoRingtones
# sem tipo
# sem familia
# com.IDTGlobal.NailArtMaster
# sem tipo
# sem familia
# com.hotslotsmachine.game
# sem tipo
# sem familia
# com.nappsstudio.hidden.camera
# sem tipo
# sem familia
# com.traber.blueappsender
# sem tipo
# sem familia
# com.kreateef.cutilah
# sem tipo
# sem familia
# com.handtechnics.hsk1heropro
# sem tipo
# sem familia
# com.sbcevangelists
# sem tipo
# sem familia
# com.studytabledesign.hyuapp
# sem tipo
# sem familia
# com.omeletteapp.fencedesign
# sem tipo
# sem familia
# clark_and_company.talkclock_restart
# sem tipo
# sem familia
# com.BestOrnamentalPlateDesign.BEJO
# sem tipo
# sem familia
# edu.alfaisal.myalfaisal2
# sem tipo
# sem familia
# com.icecreamstickcraft.pinaozora
# sem tipo
# sem familia
# com.olicar.PongzyVR
# sem tipo
# sem familia
# com.androidappsvilla.bedroomdesignideas
# sem tipo
# sem familia
# com.unlock.samsung
# sem tipo
# sem familia
# com.batikcouple.btxandro
# sem tipo
# sem familia
# com.us.ludosmart
# sem tipo
# sem familia
# com.TheLatestSleeplightDesign.myapp
# sem tipo
# sem familia
# com.car.parking
# sem tipo
# sem familia
# com.altarsoft.photoeffects
# Requested API level 29 is larger than maximum we have, returning API level 28 instead.
# sem tipo
# sem familia
# com.ffour.android.telugulovesong
# sem tipo
# sem familia
# soft98.madahi
# sem tipo
# sem familia
# com.bonsaidesignforbeginners.farah
# sem tipo
# sem familia
# com.virtlab.rotational_motion_with_uniform_acceleration_demo
# sem tipo
# sem familia
# fr.motelservices.tva
# sem tipo
# sem familia
# com.fyxtech.yoyolive
# sem tipo
# sem familia
# com.dishesdesigns.cidut
# sem tipo
# sem familia
# com.omeletteapp.humananatomy
# sem tipo
# sem familia
# bible.frenchbible.romanianbible
# sem tipo
# sem familia
# com.gb.police.bike.shooter.gangster.chase
# sem tipo
# sem familia
# com.stonepoleapps.comfortableheels
# sem tipo
# sem familia
# com.FunnyAppXL.TranslatorForCatsLanguage
# sem tipo
# sem familia
# com.marathi.lernhyds
# sem tipo
# sem familia
# com.enmedio.app
# sem tipo
# sem familia
# tornados.tormenta.rayos
# sem tipo
# sem familia
# dmcy.co.dmcy
# sem tipo
# sem familia
# com.AnkaraFashionStyles.sitd212
# sem tipo
# sem familia
# com.brudawg.diydawg
# sem tipo
# sem familia
# www.oehsindia.com.oehsindia
# sem tipo
# sem familia
# com.appnyoudev14.aghani_wasouf
# sem tipo
# sem familia
# ru.bartex.p010_train
# sem tipo
# sem familia
# de.unitedkiosk.gg.yourdog
# sem tipo
# sem familia
# com.haier.uhome.haiergoodairabroad
# sem tipo
# sem familia
# com.infigames.babycomputer
# sem tipo
# sem familia
# com.i8dudata.imgrecover.free
# sem tipo
# sem familia
# com.HoloKami.BetsHelper
# sem tipo
# sem familia
# electronicselectrical.com.electricalmachinelearn
# sem tipo
# sem familia
# stelle.altervista.org.thedivineoracle
# sem tipo
# sem familia
# com.perception.soc.en
# sem tipo
# sem familia
# com.mimpimelihatbalon.appberkahdanbarokah.forextradingonline
# sem tipo
# sem familia
# com.offf.maskk
# sem tipo
# sem familia
# com.dialerfasttele.app
# sem tipo
# sem familia
# com.TeknikHidroponik.azizahdeveloper
# sem tipo
# sem familia
# hippiechicstyle.es
# sem tipo
# sem familia
# balibuda.app
# sem tipo
# sem familia
# com.lifeapps.woodenwindowdesigns
# sem tipo
# sem familia
# com.shoutcast.stm.lasabrosita
# sem tipo
# sem familia
# tokyo.antivirus.cleanvirus
# sem tipo
# sem familia
# com.Hoodiedesign.iraonestudio
# sem tipo
# sem familia
# com.ZipasGames.Frontier
# sem tipo
# sem familia
# com.playjoysapps.worddict
# sem tipo
# sem familia
# com.maternityfashionstyles.hexadina
# sem tipo
# sem familia
# com.JapaneseGardenDesign.annisaapps
# sem tipo
# sem familia
# com.Mhedi_Ganjehzadegan.Luculent_Ligature
# sem tipo
# sem familia
# com.maruti.allah.keypad.passcode.lock.screen
# sem tipo
# sem familia
# com.AffiliatePortal
# sem tipo
# sem familia
# com.BonsaiArts.trascodroid
# sem tipo
# sem familia
# com.WomenSummerDress.trascodroid
# sem tipo
# sem familia
# fotovideo.web.id.fotovideowebapkdeveloper
# sem tipo
# sem familia
# com.zgkxzx.zxufo
# sem tipo
# sem familia
# com.kansascity.kuhoops
# sem tipo
# sem familia
# com.status.love.shayariapp.holi.colour
# sem tipo
# sem familia
# com.fta.laguindialengkap.soundtrack.sinetron.gudang.terbaru
# sem tipo
# sem familia
# com.mohcinaz.recipes1
# sem tipo
# sem familia
# com.thinkbox.flipthegun
# sem tipo
# sem familia
# com.swftcoin.client.android
# sem tipo
# sem familia
# com.a15augustphotoframe.independenceday.dual.photo.frames
# sem tipo
# sem familia
# antoniocerrone.com
# sem tipo
# sem familia
# com.KumpulanNaskahPidatoLengkap.Rayadeveloper
# sem tipo
# sem familia
# com.yanggis.chinatunnel
# sem tipo
# sem familia
# com.arkids.arpaintings
# sem tipo
# sem familia
# com.lutzjesco.smallchlorgaspublic
# sem tipo
# sem familia
# com.arabiccalligraphynameideas.ghock
# sem tipo
# sem familia
# com.kumpulankataucapanhariminggu.newellaalay.donateyourcarsacramento
# sem tipo
# sem familia
# com.towmschang.invoicing_table
# sem tipo
# sem familia
# com.snapsticker.facemakeup.photomaker
# XML Seems to be packed, operations on the AndroidManifest.xml might fail.
# sem tipo
# sem familia
# chinese.ulearning.com.vn
# sem tipo
# sem familia

# %%
data.to_csv('datasetFabricio.csv')

# %%
data
